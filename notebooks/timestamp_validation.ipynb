# %%
import pandas as pd 

columns = [
    "open_time",
    "open",
    "high",
    "low",
    "close",
    "volume",
    "close_time",
    "quote_volume",
    "count",
    "taker_buy_volume",
    "taker_buy_quote_volume",
    "ignore",
]

btc = pd.read_csv(
    "../data/raw/BTCUSDT-1d-2026-01.csv",
)

print("raw open_time:")
print(btc["open_time"].head())

btc["open_time"] = pd.to_datetime(
    btc["open_time"],
    unit = "ms",
    utc = True
)

btc["close_time"] = pd.to_datetime(
    btc["close_time"],
    unit = "ms",
    utc = True
)

print("\nconverted times:")
print(btc[["open_time","close_time"]].head())

print("\ncandle spacing:")
print(btc["open_time"].diff().head())
# Out:
# raw open_time:
# 0    1767225600000
# 1    1767312000000
# 2    1767398400000
# 3    1767484800000
# 4    1767571200000
# Name: open_time, dtype: int64
#
# converted times:
#                   open_time                       close_time
# 0 2026-01-01 00:00:00+00:00 2026-01-01 23:59:59.999000+00:00
# 1 2026-01-02 00:00:00+00:00 2026-01-02 23:59:59.999000+00:00
# 2 2026-01-03 00:00:00+00:00 2026-01-03 23:59:59.999000+00:00
# 3 2026-01-04 00:00:00+00:00 2026-01-04 23:59:59.999000+00:00
# 4 2026-01-05 00:00:00+00:00 2026-01-05 23:59:59.999000+00:00
#
# candle spacing:
# 0      NaT
# 1   1 days
# 2   1 days
# 3   1 days
# 4   1 days
# Name: open_time, dtype: timedelta64[ms]

# %%
import pandas as pd 

columns = [
    "open_time",
    "open",
    "high",
    "low",
    "close",
    "volume",
    "close_time",
    "quote_volume",
    "count",
    "taker_buy_volume",
    "taker_buy_quote_volume",
    "ignore",
]

btc = pd.read_csv(
    "../data/raw/BTCUSDT-5m-2026-01.csv",
)

print("raw open_time:")
print(btc["open_time"].head())

btc["open_time"] = pd.to_datetime(
    btc["open_time"],
    unit = "ms",
    utc = True
)

btc["close_time"] = pd.to_datetime(
    btc["close_time"],
    unit = "ms",
    utc = True
)

print("\nconverted times:")
print(btc[["open_time","close_time"]].head())

print("\ncandle spacing:")
print(btc["open_time"].diff().head())
# Out:
# raw open_time:
# 0    1767225600000
# 1    1767225900000
# 2    1767226200000
# 3    1767226500000
# 4    1767226800000
# Name: open_time, dtype: int64
#
# converted times:
#                   open_time                       close_time
# 0 2026-01-01 00:00:00+00:00 2026-01-01 00:04:59.999000+00:00
# 1 2026-01-01 00:05:00+00:00 2026-01-01 00:09:59.999000+00:00
# 2 2026-01-01 00:10:00+00:00 2026-01-01 00:14:59.999000+00:00
# 3 2026-01-01 00:15:00+00:00 2026-01-01 00:19:59.999000+00:00
# 4 2026-01-01 00:20:00+00:00 2026-01-01 00:24:59.999000+00:00
#
# candle spacing:
# 0               NaT
# 1   0 days 00:05:00
# 2   0 days 00:05:00
# 3   0 days 00:05:00
# 4   0 days 00:05:00
# Name: open_time, dtype: timedelta64[ms]

# %%
import pandas as pd 

columns = [
    "open_time",
    "open",
    "high",
    "low",
    "close",
    "volume",
    "close_time",
    "quote_volume",
    "count",
    "taker_buy_volume",
    "taker_buy_quote_volume",
    "ignore",
]

btc = pd.read_csv(
    "../data/raw/BTCUSDT-1d-2026-02.csv",
)

print("raw open_time:")
print(btc["open_time"].head())

btc["open_time"] = pd.to_datetime(
    btc["open_time"],
    unit = "ms",
    utc = True
)

btc["close_time"] = pd.to_datetime(
    btc["close_time"],
    unit = "ms",
    utc = True
)

print("\nconverted times:")
print(btc[["open_time","close_time"]].head())

print("\ncandle spacing:")
print(btc["open_time"].diff().head())
# Out:
# raw open_time:
# 0    1769904000000
# 1    1769990400000
# 2    1770076800000
# 3    1770163200000
# 4    1770249600000
# Name: open_time, dtype: int64
#
# converted times:
#                   open_time                       close_time
# 0 2026-02-01 00:00:00+00:00 2026-02-01 23:59:59.999000+00:00
# 1 2026-02-02 00:00:00+00:00 2026-02-02 23:59:59.999000+00:00
# 2 2026-02-03 00:00:00+00:00 2026-02-03 23:59:59.999000+00:00
# 3 2026-02-04 00:00:00+00:00 2026-02-04 23:59:59.999000+00:00
# 4 2026-02-05 00:00:00+00:00 2026-02-05 23:59:59.999000+00:00
#
# candle spacing:
# 0      NaT
# 1   1 days
# 2   1 days
# 3   1 days
# 4   1 days
# Name: open_time, dtype: timedelta64[ms]

# %%
import pandas as pd 

columns = [
    "open_time",
    "open",
    "high",
    "low",
    "close",
    "volume",
    "close_time",
    "quote_volume",
    "count",
    "taker_buy_volume",
    "taker_buy_quote_volume",
    "ignore",
]

btc = pd.read_csv(
    "../data/raw/BTCUSDT-5m-2026-02.csv",
)

print("raw open_time:")
print(btc["open_time"].head())

btc["open_time"] = pd.to_datetime(
    btc["open_time"],
    unit = "ms",
    utc = True
)

btc["close_time"] = pd.to_datetime(
    btc["close_time"],
    unit = "ms",
    utc = True
)

print("\nconverted times:")
print(btc[["open_time","close_time"]].head())

print("\ncandle spacing:")
print(btc["open_time"].diff().head())
# Out:
# raw open_time:
# 0    1769904000000
# 1    1769904300000
# 2    1769904600000
# 3    1769904900000
# 4    1769905200000
# Name: open_time, dtype: int64
#
# converted times:
#                   open_time                       close_time
# 0 2026-02-01 00:00:00+00:00 2026-02-01 00:04:59.999000+00:00
# 1 2026-02-01 00:05:00+00:00 2026-02-01 00:09:59.999000+00:00
# 2 2026-02-01 00:10:00+00:00 2026-02-01 00:14:59.999000+00:00
# 3 2026-02-01 00:15:00+00:00 2026-02-01 00:19:59.999000+00:00
# 4 2026-02-01 00:20:00+00:00 2026-02-01 00:24:59.999000+00:00
#
# candle spacing:
# 0               NaT
# 1   0 days 00:05:00
# 2   0 days 00:05:00
# 3   0 days 00:05:00
# 4   0 days 00:05:00
# Name: open_time, dtype: timedelta64[ms]

# %%
import pandas as pd 

columns = [
    "open_time",
    "open",
    "high",
    "low",
    "close",
    "volume",
    "close_time",
    "quote_volume",
    "count",
    "taker_buy_volume",
    "taker_buy_quote_volume",
    "ignore",
]

btc = pd.read_csv(
    "../data/raw/BTCUSDT-1d-2026-03.csv",
)

print("raw open_time:")
print(btc["open_time"].head())

btc["open_time"] = pd.to_datetime(
    btc["open_time"],
    unit = "ms",
    utc = True
)

btc["close_time"] = pd.to_datetime(
    btc["close_time"],
    unit = "ms",
    utc = True
)

print("\nconverted times:")
print(btc[["open_time","close_time"]].head())

print("\ncandle spacing:")
print(btc["open_time"].diff().head())
# Out:
# raw open_time:
# 0    1772323200000
# 1    1772409600000
# 2    1772496000000
# 3    1772582400000
# 4    1772668800000
# Name: open_time, dtype: int64
#
# converted times:
#                   open_time                       close_time
# 0 2026-03-01 00:00:00+00:00 2026-03-01 23:59:59.999000+00:00
# 1 2026-03-02 00:00:00+00:00 2026-03-02 23:59:59.999000+00:00
# 2 2026-03-03 00:00:00+00:00 2026-03-03 23:59:59.999000+00:00
# 3 2026-03-04 00:00:00+00:00 2026-03-04 23:59:59.999000+00:00
# 4 2026-03-05 00:00:00+00:00 2026-03-05 23:59:59.999000+00:00
#
# candle spacing:
# 0      NaT
# 1   1 days
# 2   1 days
# 3   1 days
# 4   1 days
# Name: open_time, dtype: timedelta64[ms]

# %%
import pandas as pd 

columns = [
    "open_time",
    "open",
    "high",
    "low",
    "close",
    "volume",
    "close_time",
    "quote_volume",
    "count",
    "taker_buy_volume",
    "taker_buy_quote_volume",
    "ignore",
]

btc = pd.read_csv(
    "../data/raw/BTCUSDT-5m-2026-03.csv",
)

print("raw open_time:")
print(btc["open_time"].head())

btc["open_time"] = pd.to_datetime(
    btc["open_time"],
    unit = "ms",
    utc = True
)

btc["close_time"] = pd.to_datetime(
    btc["close_time"],
    unit = "ms",
    utc = True
)

print("\nconverted times:")
print(btc[["open_time","close_time"]].head())

print("\ncandle spacing:")
print(btc["open_time"].diff().head())
# Out:
# raw open_time:
# 0    1772323200000
# 1    1772323500000
# 2    1772323800000
# 3    1772324100000
# 4    1772324400000
# Name: open_time, dtype: int64
#
# converted times:
#                   open_time                       close_time
# 0 2026-03-01 00:00:00+00:00 2026-03-01 00:04:59.999000+00:00
# 1 2026-03-01 00:05:00+00:00 2026-03-01 00:09:59.999000+00:00
# 2 2026-03-01 00:10:00+00:00 2026-03-01 00:14:59.999000+00:00
# 3 2026-03-01 00:15:00+00:00 2026-03-01 00:19:59.999000+00:00
# 4 2026-03-01 00:20:00+00:00 2026-03-01 00:24:59.999000+00:00
#
# candle spacing:
# 0               NaT
# 1   0 days 00:05:00
# 2   0 days 00:05:00
# 3   0 days 00:05:00
# 4   0 days 00:05:00
# Name: open_time, dtype: timedelta64[ms]

# %%
import pandas as pd 

columns = [
    "open_time",
    "open",
    "high",
    "low",
    "close",
    "volume",
    "close_time",
    "quote_volume",
    "count",
    "taker_buy_volume",
    "taker_buy_quote_volume",
    "ignore",
]

btc = pd.read_csv(
    "../data/raw/BTCUSDT-1d-2026-04.csv",
)

print("raw open_time:")
print(btc["open_time"].head())

btc["open_time"] = pd.to_datetime(
    btc["open_time"],
    unit = "ms",
    utc = True
)

btc["close_time"] = pd.to_datetime(
    btc["close_time"],
    unit = "ms",
    utc = True
)

print("\nconverted times:")
print(btc[["open_time","close_time"]].head())

print("\ncandle spacing:")
print(btc["open_time"].diff().head())
# Out:
# raw open_time:
# 0    1775001600000
# 1    1775088000000
# 2    1775174400000
# 3    1775260800000
# 4    1775347200000
# Name: open_time, dtype: int64
#
# converted times:
#                   open_time                       close_time
# 0 2026-04-01 00:00:00+00:00 2026-04-01 23:59:59.999000+00:00
# 1 2026-04-02 00:00:00+00:00 2026-04-02 23:59:59.999000+00:00
# 2 2026-04-03 00:00:00+00:00 2026-04-03 23:59:59.999000+00:00
# 3 2026-04-04 00:00:00+00:00 2026-04-04 23:59:59.999000+00:00
# 4 2026-04-05 00:00:00+00:00 2026-04-05 23:59:59.999000+00:00
#
# candle spacing:
# 0      NaT
# 1   1 days
# 2   1 days
# 3   1 days
# 4   1 days
# Name: open_time, dtype: timedelta64[ms]

# %%
import pandas as pd 

columns = [
    "open_time",
    "open",
    "high",
    "low",
    "close",
    "volume",
    "close_time",
    "quote_volume",
    "count",
    "taker_buy_volume",
    "taker_buy_quote_volume",
    "ignore",
]

btc = pd.read_csv(
    "../data/raw/BTCUSDT-5m-2026-04.csv",
)

print("raw open_time:")
print(btc["open_time"].head())

btc["open_time"] = pd.to_datetime(
    btc["open_time"],
    unit = "ms",
    utc = True
)

btc["close_time"] = pd.to_datetime(
    btc["close_time"],
    unit = "ms",
    utc = True
)

print("\nconverted times:")
print(btc[["open_time","close_time"]].head())

print("\ncandle spacing:")
print(btc["open_time"].diff().head())
# Out:
# raw open_time:
# 0    1775001600000
# 1    1775001900000
# 2    1775002200000
# 3    1775002500000
# 4    1775002800000
# Name: open_time, dtype: int64
#
# converted times:
#                   open_time                       close_time
# 0 2026-04-01 00:00:00+00:00 2026-04-01 00:04:59.999000+00:00
# 1 2026-04-01 00:05:00+00:00 2026-04-01 00:09:59.999000+00:00
# 2 2026-04-01 00:10:00+00:00 2026-04-01 00:14:59.999000+00:00
# 3 2026-04-01 00:15:00+00:00 2026-04-01 00:19:59.999000+00:00
# 4 2026-04-01 00:20:00+00:00 2026-04-01 00:24:59.999000+00:00
#
# candle spacing:
# 0               NaT
# 1   0 days 00:05:00
# 2   0 days 00:05:00
# 3   0 days 00:05:00
# 4   0 days 00:05:00
# Name: open_time, dtype: timedelta64[ms]
